# %%
import pandas as pd

# %%
df = pd.read_csv("students.csv")

# %%
df
# Out:
#       Name  Age  Marks       City
# 0  Taimoor   20     85  Islamabad
# 1    Ahmed   21     72     Lahore
# 2      Ali   20     91    Karachi
# 3    Usman   22     65  Islamabad
# 4    Hamza   21     78     Lahore
# 5   Ayesha   20     95    Karachi
# 6    Bilal   23     55  Islamabad
# 7  Mahnoor   21     88     Lahore
# 8    Rafay   22     67    Karachi
# 9   Fatima   20     92  Islamabad

# %%
df.head()
# Out:
#       Name  Age  Marks       City
# 0  Taimoor   20     85  Islamabad
# 1    Ahmed   21     72     Lahore
# 2      Ali   20     91    Karachi
# 3    Usman   22     65  Islamabad
# 4    Hamza   21     78     Lahore

# %%
df.tail()
# Out:
#       Name  Age  Marks       City
# 5   Ayesha   20     95    Karachi
# 6    Bilal   23     55  Islamabad
# 7  Mahnoor   21     88     Lahore
# 8    Rafay   22     67    Karachi
# 9   Fatima   20     92  Islamabad

# %%
df.shape
# Out:
# (10, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks', 'City'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   Marks   10 non-null     int64
#  3   City    10 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#              Age      Marks
# count  10.000000  10.000000
# mean   21.000000  78.800000
# std     1.054093  13.546627
# min    20.000000  55.000000
# 25%    20.000000  68.250000
# 50%    21.000000  81.500000
# 75%    21.750000  90.250000
# max    23.000000  95.000000

# %%
df["Marks"]
# Out:
# 0    85
# 1    72
# 2    91
# 3    65
# 4    78
# 5    95
# 6    55
# 7    88
# 8    67
# 9    92
# Name: Marks, dtype: int64

# %%
df["Name"]
# Out:
# 0    Taimoor
# 1      Ahmed
# 2        Ali
# 3      Usman
# 4      Hamza
# 5     Ayesha
# 6      Bilal
# 7    Mahnoor
# 8      Rafay
# 9     Fatima
# Name: Name, dtype: object

# %%
df[["Name", "Marks"]]
# Out:
#       Name  Marks
# 0  Taimoor     85
# 1    Ahmed     72
# 2      Ali     91
# 3    Usman     65
# 4    Hamza     78
# 5   Ayesha     95
# 6    Bilal     55
# 7  Mahnoor     88
# 8    Rafay     67
# 9   Fatima     92

# %%
df.iloc[0]
# Out:
# Name       Taimoor
# Age             20
# Marks           85
# City     Islamabad
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#       Name  Age  Marks       City
# 0  Taimoor   20     85  Islamabad
# 1    Ahmed   21     72     Lahore
# 2      Ali   20     91    Karachi

# %%
df.iloc[0, 2]
# Out:
# np.int64(85)

# %%
df[df["Marks"] > 70]
# Out:
#       Name  Age  Marks       City
# 0  Taimoor   20     85  Islamabad
# 1    Ahmed   21     72     Lahore
# 2      Ali   20     91    Karachi
# 4    Hamza   21     78     Lahore
# 5   Ayesha   20     95    Karachi
# 7  Mahnoor   21     88     Lahore
# 9   Fatima   20     92  Islamabad

# %%
df[df["Marks"] < 70]
# Out:
#     Name  Age  Marks       City
# 3  Usman   22     65  Islamabad
# 6  Bilal   23     55  Islamabad
# 8  Rafay   22     67    Karachi

# %%
df[df["Age"] == 20]
# Out:
#       Name  Age  Marks       City
# 0  Taimoor   20     85  Islamabad
# 2      Ali   20     91    Karachi
# 5   Ayesha   20     95    Karachi
# 9   Fatima   20     92  Islamabad

# %%
df[df["City"] == "Islamabad"]
# Out:
#       Name  Age  Marks       City
# 0  Taimoor   20     85  Islamabad
# 3    Usman   22     65  Islamabad
# 6    Bilal   23     55  Islamabad
# 9   Fatima   20     92  Islamabad

# %%
df[(df["Marks"] > 80) & (df["Age"] < 21)]
# Out:
#       Name  Age  Marks       City
# 0  Taimoor   20     85  Islamabad
# 2      Ali   20     91    Karachi
# 5   Ayesha   20     95    Karachi
# 9   Fatima   20     92  Islamabad

# %%
df["Marks"].mean()
# Out:
# np.float64(78.8)

# %%
df["Marks"].max()
# Out:
# 95

# %%
df["Marks"].min()
# Out:
# 55

# %%
df["Marks"].sum()
# Out:
# np.int64(788)

# %%
df["Marks"].median()
# Out:
# 81.5

# %%
import numpy as np

# %%
numbers = np.array([11, 12, 13, 14, 15])

# %%
print(numbers)
# Out:
# [11 12 13 14 15]

# %%
np.mean(numbers)
# Out:
# np.float64(13.0)

# %%
np.min(numbers)
# Out:
# np.int64(11)

# %%
np.max(numbers)
# Out:
# np.int64(15)

# %%
np.sum(numbers)
# Out:
# np.int64(65)

# %%
arr = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.ndim
# Out:
# 2
